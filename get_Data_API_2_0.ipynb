# %% [markdown]
# <a href="https://colab.research.google.com/github/SM24-Industrial-Software-Dev/ML-forecasting-NOx-levels/blob/get_Data-API/get_Data_API_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
from google.api_core import retry
from IPython.display import HTML, Image
from matplotlib import pyplot as plt
import seaborn as sns
from numpy.lib import recfunctions as rfn

import concurrent
import ee
import geemap
import google
import io
import multiprocessing
import numpy as np
import requests
import tensorflow as tf
import pandas as pd
import math


# REPLACE WITH YOUR PROJECT!
PROJECT = 'yu-summer-2024'

auth.authenticate_user()


credentials, _ = google.auth.default()
ee.Initialize(credentials, project=PROJECT, opt_url='https://earthengine-highvolume.googleapis.com')

# %%
import geopy
# importing geopy library
from geopy.geocoders import Nominatim
loc = Nominatim(user_agent="GetLoc")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import geopy
# importing geopy library
from geopy.geocoders import Nominatim

def get_Data(locations, sdate, edate, cloudmasking):
  loc = Nominatim(user_agent="GetLoc")

  adminUnits=ee.FeatureCollection(
    'FAO/GAUL_SIMPLIFIED_500m/2015/level2')

  geoCollection = []
  for location in locations:
          getloc = loc.geocode(location)
          coordinates = ee.Geometry.Point(getloc.longitude, getloc.latitude)
          geoCollection.append(ee.Feature(coordinates, {'region': location}))


  geometries = ee.FeatureCollection(geoCollection)

  adminSelect=adminUnits.filterBounds(geometries)

  def copyGeometryProps(index):
      source = ee.Feature(geometries.toList(geometries.size()).get(index))
      dest = ee.Feature(adminSelect.toList(adminSelect.size()).get(index))
      ftr = dest.copyProperties(source)
      return ftr

  seq = ee.List.sequence(0, adminSelect.size().subtract(1))
  adminSelect = ee.FeatureCollection(seq.map(copyGeometryProps))

  no2Raw = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_NO2')

  CLOUD_MASK_FRACTION = cloudmasking # You can play around with this value.
  def maskClouds(image):
    cf = image.select('cloud_fraction')
    mask=cf.lte(CLOUD_MASK_FRACTION)
    return image.updateMask(mask).copyProperties(image)

  # get start and end dates for sentinel 5P data
  try:
    startDate = ee.Date(sdate)
    endDate = ee.Date(edate)
  except:
    print("Invalid dates")
    return None

  ndays = endDate.difference(startDate, 'days')

  def create_date_list_fn(startDate):
    def date_list_fn(days):
      return startDate.advance(days, 'days')
    return date_list_fn

  # generate the list of dates

  date_list_fn = create_date_list_fn(startDate)
  list_of_dates = ee.List.sequence(0, ndays, 1).map(date_list_fn)

  def image_mediancomposite_by_date(date):
    return ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_NO2')\
    .filterDate(ee.Date(date), ee.Date(date).advance(1, 'day'))\
    .map(maskClouds) \
    .select('tropospheric_NO2_column_number_density')\
    .median()\
    .set('system:time_start', ee.Date(date).millis())

  no2 = ee.ImageCollection(
        ee.List.sequence(0, ndays, 1)\
        .map(date_list_fn)\
        .map(image_mediancomposite_by_date)
      )


  def createConc(img, collectionLabel):

        def getConc(img):
            no2Mean=img.reduceRegion(
                  reducer = ee.Reducer.mean(),
                  geometry = adminSelect.geometry(),
                  scale =  7000
                ).get('tropospheric_NO2_column_number_density')

            region = img.get('region')

            doy=img.date().getRelative('day', 'year')
            dow=img.date().format('E')
            dt=img.date().format("YYYY-MM-dd")


            # Handle potential missing values
            feature_dict = {
                'DOY': doy,
                'DOW': dow,
                'DATE': dt,
                'type': collectionLabel,
            }
            if no2Mean:
                feature_dict['conc'] = no2Mean
                return adminSelect.map(lambda f: f.set(feature_dict)).first()
            else:
                return None

        return getConc(img)

  no2AggChange=no2.filterDate(startDate, endDate) \
                              .map(lambda img:createConc(img, 'lockdown')) \
                              .filter(ee.Filter.notNull(['conc']))


  def fc_to_dict(fc):
    prop_names = fc.first().propertyNames()
    prop_lists = fc.reduceColumns(
        reducer=ee.Reducer.toList().repeat(prop_names.size()),
        selectors=prop_names).get('list')

    return ee.Dictionary.fromLists(prop_names, prop_lists)

  NO2_stat_dict = fc_to_dict(no2AggChange).getInfo()
  NO2_stat_df = pd.DataFrame(NO2_stat_dict)
  NO2_stat_df['region'] = [f['properties']['region'] for f in no2AggChange.getInfo()['features']]

  print(NO2_stat_df)
  return NO2_stat_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
get_Data(["Allentown", "New York", "Boston"], "2020-03-01", "2020-05-01", 0.3)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     ADM0_CODE                 ADM0_NAME  ADM1_CODE      ADM1_NAME  ADM2_CODE  \
# 0         259  United States of America       3235  Massachusetts      29907
# 1         259  United States of America       3235  Massachusetts      29907
# 2         259  United States of America       3235  Massachusetts      29907
# 3         259  United States of America       3235  Massachusetts      29907
# 4         259  United States of America       3235  Massachusetts      29907
# 5         259  United States of America       3235  Massachusetts      29907
# 6         259  United States of America       3235  Massachusetts      29907
# 7         259  United States of America       3235  Massachusetts      29907
# 8         259  United States of America       3235  Massachusetts      29907
# 9         259  United States of America       3235  Massachusetts      29907
# 10        259  United States of America       3235  Massachusetts      29907
# 11        259  United States of America       3235  Massachusetts      29907
# 12        259  United States of America       3235  Massachusetts      29907
# 13        259  United States of America       3235  Massachusetts      29907
# 14        259  United States of America       3235  Massachusetts      29907
# 15        259  United States of America       3235  Massachusetts      29907
# 16        259  United States of America       3235  Massachusetts      29907
# 17        259  United States of America       3235  Massachusetts      29907
# 18        259  United States of America       3235  Massachusetts      29907
# 19        259  United States of America       3235  Massachusetts      29907
# 20        259  United States of America       3235  Massachusetts      29907
# 21        259  United States of America       3235  Massachusetts      29907
# 22        259  United States of America       3235  Massachusetts      29907
# 23        259  United States of America       3235  Massachusetts      29907
# 24        259  United States of America       3235  Massachusetts      29907
# 25        259  United States of America       3235  Massachusetts      29907
# 26        259  United States of America       3235  Massachusetts      29907
# 27        259  United States of America       3235  Massachusetts      29907
# 28        259  United States of America       3235  Massachusetts      29907
# 29        259  United States of America       3235  Massachusetts      29907
# 30        259  United States of America       3235  Massachusetts      29907
# 31        259  United States of America       3235  Massachusetts      29907
# 32        259  United States of America       3235  Massachusetts      29907
# 33        259  United States of America       3235  Massachusetts      29907
# 34        259  United States of America       3235  Massachusetts      29907
# 35        259  United States of America       3235  Massachusetts      29907
# 36        259  United States of America       3235  Massachusetts      29907
# 37        259  United States of America       3235  Massachusetts      29907
# 38        259  United States of America       3235  Massachusetts      29907
# 39        259  United States of America       3235  Massachusetts      29907
# 40        259  United States of America       3235  Massachusetts      29907
# 41        259  United States of America       3235  Massachusetts      29907
#
#    ADM2_NAME        DATE DISP_AREA  DOW  DOY  EXP2_YEAR        STATUS  \
# 0    Suffolk  2020-03-01        NO  Sun   60       3000  Member State
# 1    Suffolk  2020-03-02        NO  Mon   61       3000  Member State
# 2    Suffolk  2020-03-03        NO  Tue   62       3000  Member State
# 3    Suffolk  2020-03-04        NO  Wed   63       3000  Member State
# 4    Suffolk  2020-03-05        NO  Thu   64       3000  Member State
# 5    Suffolk  2020-03-07        NO  Sat   66       3000  Member State
# 6    Suffolk  2020-03-08        NO  Sun   67       3000  Member State
# 7    Suffolk  2020-03-09        NO  Mon   68       3000  Member State
# 8    Suffolk  2020-03-10        NO  Tue   69       3000  Member State
# 9    Suffolk  2020-03-11        NO  Wed   70       3000  Member State
# 10   Suffolk  2020-03-13        NO  Fri   72       3000  Member State
# 11   Suffolk  2020-03-14        NO  Sat   73       3000  Member State
# 12   Suffolk  2020-03-15        NO  Sun   74       3000  Member State
# 13   Suffolk  2020-03-16        NO  Mon   75       3000  Member State
# 14   Suffolk  2020-03-18        NO  Wed   77       3000  Member State
# 15   Suffolk  2020-03-21        NO  Sat   80       3000  Member State
# 16   Suffolk  2020-03-22        NO  Sun   81       3000  Member State
# 17   Suffolk  2020-03-24        NO  Tue   83       3000  Member State
# 18   Suffolk  2020-03-26        NO  Thu   85       3000  Member State
# 19   Suffolk  2020-03-27        NO  Fri   86       3000  Member State
# 20   Suffolk  2020-03-31        NO  Tue   90       3000  Member State
# 21   Suffolk  2020-04-01        NO  Wed   91       3000  Member State
# 22   Suffolk  2020-04-02        NO  Thu   92       3000  Member State
# 23   Suffolk  2020-04-04        NO  Sat   94       3000  Member State
# 24   Suffolk  2020-04-05        NO  Sun   95       3000  Member State
# 25   Suffolk  2020-04-06        NO  Mon   96       3000  Member State
# 26   Suffolk  2020-04-07        NO  Tue   97       3000  Member State
# 27   Suffolk  2020-04-08        NO  Wed   98       3000  Member State
# 28   Suffolk  2020-04-09        NO  Thu   99       3000  Member State
# 29   Suffolk  2020-04-11        NO  Sat  101       3000  Member State
# 30   Suffolk  2020-04-12        NO  Sun  102       3000  Member State
# 31   Suffolk  2020-04-14        NO  Tue  104       3000  Member State
# 32   Suffolk  2020-04-15        NO  Wed  105       3000  Member State
# 33   Suffolk  2020-04-16        NO  Thu  106       3000  Member State
# 34   Suffolk  2020-04-17        NO  Fri  107       3000  Member State
# 35   Suffolk  2020-04-19        NO  Sun  109       3000  Member State
# 36   Suffolk  2020-04-20        NO  Mon  110       3000  Member State
# 37   Suffolk  2020-04-22        NO  Wed  112       3000  Member State
# 2    Suffolk  2020-03-03        NO  Tue   62       3000  Member State
# 3    Suffolk  2020-03-04        NO  Wed   63       3000  Member State
# 4    Suffolk  2020-03-05        NO  Thu   64       3000  Member State
# 5    Suffolk  2020-03-07        NO  Sat   66       3000  Member State
# 6    Suffolk  2020-03-08        NO  Sun   67       3000  Member State
# 7    Suffolk  2020-03-09        NO  Mon   68       3000  Member State
# 8    Suffolk  2020-03-10        NO  Tue   69       3000  Member State
# 9    Suffolk  2020-03-11        NO  Wed   70       3000  Member State
# 10   Suffolk  2020-03-13        NO  Fri   72       3000  Member State
# 11   Suffolk  2020-03-14        NO  Sat   73       3000  Member State
# 12   Suffolk  2020-03-15        NO  Sun   74       3000  Member State
# 13   Suffolk  2020-03-16        NO  Mon   75       3000  Member State
# 14   Suffolk  2020-03-18        NO  Wed   77       3000  Member State
# 15   Suffolk  2020-03-21        NO  Sat   80       3000  Member State
# 16   Suffolk  2020-03-22        NO  Sun   81       3000  Member State
# 17   Suffolk  2020-03-24        NO  Tue   83       3000  Member State
# 18   Suffolk  2020-03-26        NO  Thu   85       3000  Member State
# 19   Suffolk  2020-03-27        NO  Fri   86       3000  Member State
# 20   Suffolk  2020-03-31        NO  Tue   90       3000  Member State
# 21   Suffolk  2020-04-01        NO  Wed   91       3000  Member State
# 22   Suffolk  2020-04-02        NO  Thu   92       3000  Member State
# 23   Suffolk  2020-04-04        NO  Sat   94       3000  Member State
# 24   Suffolk  2020-04-05        NO  Sun   95       3000  Member State
# 25   Suffolk  2020-04-06        NO  Mon   96       3000  Member State
# 26   Suffolk  2020-04-07        NO  Tue   97       3000  Member State
# 27   Suffolk  2020-04-08        NO  Wed   98       3000  Member State
# 28   Suffolk  2020-04-09        NO  Thu   99       3000  Member State
# 29   Suffolk  2020-04-11        NO  Sat  101       3000  Member State
# 30   Suffolk  2020-04-12        NO  Sun  102       3000  Member State
# 31   Suffolk  2020-04-14        NO  Tue  104       3000  Member State
# 32   Suffolk  2020-04-15        NO  Wed  105       3000  Member State
# 33   Suffolk  2020-04-16        NO  Thu  106       3000  Member State
# 34   Suffolk  2020-04-17        NO  Fri  107       3000  Member State
# 35   Suffolk  2020-04-19        NO  Sun  109       3000  Member State
# 36   Suffolk  2020-04-20        NO  Mon  110       3000  Member State
# 37   Suffolk  2020-04-22        NO  Wed  112       3000  Member State
# 38   Suffolk  2020-04-23        NO  Thu  113       3000  Member State
# 39   Suffolk  2020-04-25        NO  Sat  115       3000  Member State
# 40   Suffolk  2020-04-28        NO  Tue  118       3000  Member State
# 41   Suffolk  2020-04-29        NO  Wed  119       3000  Member State
#
#     STR2_YEAR  Shape_Area  Shape_Leng      conc     region system:index  \
# 0        1000    0.017067    2.345468  0.000033  Allentown            0
# 1        1000    0.017067    2.345468  0.000102  Allentown            1
# 2        1000    0.017067    2.345468  0.000131  Allentown            2
# 3        1000    0.017067    2.345468  0.000045  Allentown            3
